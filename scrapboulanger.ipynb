# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup


# Définition de l'User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'
}

url = 'https://www.boulanger.com/c/montre-connectee',

# Stockage des résultats
all_data = []

# Fonction de scraping
def scrape_product(url):
    try:
        response = requests.get(url, headers=headers, timeout=90)
        response.raise_for_status()  # Vérification des erreurs HTTP
        soup = BeautifulSoup(response.content, 'html.parser')

        
     
        items = soup.select(f'#product-list > ul > li > article')#main > div.grid.product-list__content
            
        len(items)
        for  item in items :
                title = item.select_one('#productLabel')
                price= item.select_one('.product-list__product-area-3.g-col-5.g-col-sm-7.g-col-md-4.g-start-md-9.g-col-lg-3.g-start-lg-7.g-col-xl-3.g-start-xl-7 > div > p')
                rating = item.select_one('.product-list__product-area-2.g-col-5.g-col-sm-7.g-col-md-4.g-col-lg-3.g-col-xl-3 > div.product-list__product-rating > a > div > bl-rating')
                reviews = item.select_one('.product-list__product-area-2.g-col-5.g-col-sm-7.g-col-md-4.g-col-lg-3.g-col-xl-3 > div.product-list__product-rating > a > span')
                promo = item.select_one('.product-list__product-area-3.g-col-5.g-col-sm-7.g-col-md-4.g-start-md-9.g-col-lg-3.g-start-lg-7.g-col-xl-3.g-start-xl-7 > div > div > span.price__crossed')
                stock = item.select_one('.product-list__product-area-3.g-col-5.g-col-sm-7.g-col-md-4.g-start-md-9.g-col-lg-3.g-start-lg-7.g-col-xl-3.g-start-xl-7 > button > span')

                if title and price:
                    all_data.append({
                        'Titre': title.text.strip(),
                        'Prix (€)': price.text.replace(',', '.').strip() if price else None,
                        'Note': rating.get('rating') if rating else None,
                        'Avis': reviews.text.strip() if reviews else None,  # Boulanger ne montre pas toujours le nombre d’avis
                        'promo': promo.text.strip() if promo else "0",
                        'Stock' : 'Disponible' if stock else 'Indisponible'
                        })
                    
        print(len(items))             


    except requests.exceptions.RequestException as e:
        print(f"❌ Erreur lors de la requête : {e}")

    time.sleep(2)  # Pause pour éviter le blocage

# Exécution du scraping
for url in url:
        scrape_product(url)

# Conversion en DataFrame Pandas pour visualisation
df = pd.DataFrame(all_data)

# Affichage des résultats
print("\n📊 Résultats du scraping :")
print(df)

# Sauvegarde en CSV
df.to_csv("resultats_scrappiboul.csv", index=False)
# Out:
# 50
#
# 📊 Résultats du scraping :
#                                                 Titre Prix (€)  \
# 0   Montre connectée\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\...  219.99€
# 1   Montre connectée\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\...  699.99€
# 2   Montre connectée\n\t\t\t\t\t\t\tAPPLE WATCH\n\...  789.00€
# 3   Montre connectée\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\...  349.99€
# 4   Montre sport\n\t\t\t\t\t\t\tGARMIN\n\t\t\t\t\t...  249.99€
# 5   Montre connectée\n\t\t\t\t\t\t\tAPPLE WATCH\n\...  429.00€
# 6   Montre connectée\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\...  499.99€
# 7   Montre connectée\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t...  119.00€
# 8   Montre sport\n\t\t\t\t\t\t\tGARMIN\n\t\t\t\t\t...  499.99€
# 9   Montre connectée\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t...   79.00€
# 10  Montre sport\n\t\t\t\t\t\t\tGARMIN\n\t\t\t\t\t...  149.99€
# 11  Montre connectée\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\...  229.99€
# 12  Montre connectée\n\t\t\t\t\t\t\tAPPLE WATCH\n\...  411.99€
# 13  Montre sport\n\t\t\t\t\t\t\tGARMIN\n\t\t\t\t\t...  249.99€
# 14  Montre connectée\n\t\t\t\t\t\t\tAPPLE WATCH\n\...  249.00€
# 15  Montre sport\n\t\t\t\t\t\t\tGARMIN\n\t\t\t\t\t...  399.99€
# 16  Montre connectée\n\t\t\t\t\t\t\tAPPLE WATCH\n\...  249.00€
# 17  Montre connectée\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t...  101.08€
# 18  Montre connectée\n\t\t\t\t\t\t\tHUAWEI\n\t\t\t...  189.99€
# 19  Montre connectée\n\t\t\t\t\t\t\tAPPLE WATCH\n\...  789.00€
# 20  Montre sport\n\t\t\t\t\t\t\tGARMIN\n\t\t\t\t\t...  221.35€
# 21  Montre connectée\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t...   39.00€
# 22  Montre connectée\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\...  349.99€
# 23  Montre connectée\n\t\t\t\t\t\t\tHUAWEI\n\t\t\t...  159.99€
# 24  Montre sport\n\t\t\t\t\t\t\tGARMIN\n\t\t\t\t\t...  391.49€
# 25  Montre connectée\n\t\t\t\t\t\t\tICEWATCH\n\t\t...   49.99€
# 26  Montre connectée\n\t\t\t\t\t\t\tICEWATCH\n\t\t...   49.99€
# 27  Montre connectée\n\t\t\t\t\t\t\tHUAWEI\n\t\t\t...  359.99€
# 28  Montre connectée\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t...   34.99€
# 29  Montre sport\n\t\t\t\t\t\t\tAMAZFIT\n\t\t\t\t\...  169.99€
# 30  Montre connectée\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\...  359.99€
# 31  Montre connectée\n\t\t\t\t\t\t\tHUAWEI\n\t\t\t...  349.99€
# 32  Montre connectée\n\t\t\t\t\t\t\tAPPLE WATCH\n\...  279.00€
# 33  Montre connectée\n\t\t\t\t\t\t\tAPPLE WATCH\n\...  239.00€
# 34  Montre connectée\n\t\t\t\t\t\t\tAPPLE WATCH\n\...  789.00€
# 35  Montre connectée\n\t\t\t\t\t\t\tICEWATCH\n\t\t...   49.99€
# 36  Montre connectée\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\...  219.99€
# 37  Montre sport\n\t\t\t\t\t\t\tGARMIN\n\t\t\t\t\t...  269.99€
# 38  Montre connectée\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\...  349.99€
# 39  Montre sport\n\t\t\t\t\t\t\tGARMIN\n\t\t\t\t\t...  399.99€
# 40  Montre connectée\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\...  269.99€
# 41  Montre sport\n\t\t\t\t\t\t\tGARMIN\n\t\t\t\t\t...  989.10€
# 42  Montre santé\n\t\t\t\t\t\t\tWITHINGS\n\t\t\t\t...  279.95€
# 43  Montre sport\n\t\t\t\t\t\t\tGARMIN\n\t\t\t\t\t...  149.99€
# 44  Montre sport\n\t\t\t\t\t\t\tGARMIN\n\t\t\t\t\t...  449.99€
# 45  Montre connectée\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\...  399.99€
# 46  Montre connectée\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\...  399.99€
# 47  Montre sport\n\t\t\t\t\t\t\tGARMIN\n\t\t\t\t\t...  270.04€
# 48  Montre connectée\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\...  499.99€
# 49  Montre santé\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\...   69.99€
#
#                   Note  Avis    promo       Stock
# 0    4.070400238037109  (71)  319,90€  Disponible
# 1    4.480800151824951  (52)        0  Disponible
# 2                  5.0  (14)  855,89€  Disponible
# 3    4.247700214385986  (93)        0  Disponible
# 4    4.622000217437744  (82)  278,97€  Disponible
# 5                 None  None  569,00€  Disponible
# 6    4.593500137329102  (74)  549,99€  Disponible
# 7                  5.0   (1)        0  Disponible
# 8                 None  None        0  Disponible
# 9   4.6666998863220215   (6)        0  Disponible
# 10   4.346199989318848  (26)        0  Disponible
# 11               3.875  (16)        0  Disponible
# 12   4.759300231933594  (54)        0  Disponible
# 13   4.388899803161621  (72)  278,97€  Disponible
# 14    4.72130012512207  (61)        0  Disponible
# 15   4.800000190734863  (15)  429,99€  Disponible
# 16                 5.0   (3)        0  Disponible
# 17   4.444399833679199  (36)        0  Disponible
# 18   4.846199989318848  (13)        0  Disponible
# 19                 5.0   (3)  898,97€  Disponible
# 20   4.411799907684326  (17)        0  Disponible
# 21   4.599999904632568  (10)        0  Disponible
# 22   4.272799968719482  (55)  399,98€  Disponible
# 23   4.736800193786621  (38)        0  Disponible
# 24   4.432400226593018  (37)  429,99€  Disponible
# 25  4.6666998863220215   (3)        0  Disponible
# 26                 1.0   (1)        0  Disponible
# 27   4.800000190734863   (5)        0  Disponible
# 28                 5.0   (1)        0  Disponible
# 29  3.3333001136779785   (3)        0  Disponible
# 30                 4.5   (6)  449,90€  Disponible
# 31   4.769199848175049  (13)        0  Disponible
# 32    4.72130012512207  (61)        0  Disponible
# 33    4.72130012512207  (61)        0  Disponible
# 34                 5.0   (3)  898,97€  Disponible
# 35                None  None        0  Disponible
# 36   4.172800064086914  (81)  299,99€  Disponible
# 37   4.607100009918213  (28)        0  Disponible
# 38   4.070400238037109  (71)        0  Disponible
# 39  4.3333001136779785   (6)  429,99€  Disponible
# 40   4.070400238037109  (71)  349,90€  Disponible
# 41                None  None        0  Disponible
# 42  3.6974000930786133  (23)  349,95€  Disponible
# 43   4.800000190734863  (10)        0  Disponible
# 44                None  None        0  Disponible
# 45   4.070400238037109  (71)        0  Disponible
# 46   4.070400238037109  (71)        0  Disponible
# 47     4.3225998878479  (31)        0  Disponible
# 48   4.480800151824951  (52)  549,99€  Disponible
# 49  3.6666998863220215   (6)        0  Disponible

# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup


# Définition de l'User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'
}

url = 'https://www.boulanger.com/c/airpods',

# Stockage des résultats
all_data = []

# Fonction de scraping
def scrape_product(url):
    try:
        response = requests.get(url, headers=headers, timeout=900)
        response.raise_for_status()  # Vérification des erreurs HTTP
        soup = BeautifulSoup(response.content, 'html.parser')

        
     
        items = soup.select(f'#product-list > ul > li > article')#main > div.grid.product-list__content
            
        len(items)
        for  item in items :
                title = item.select_one('#productLabel')
                price= item.select_one('.product-list__product-area-3.g-col-5.g-col-sm-7.g-col-md-4.g-start-md-9.g-col-lg-3.g-start-lg-7.g-col-xl-3.g-start-xl-7 > div > p')
                rating = item.select_one('.product-list__product-area-2.g-col-5.g-col-sm-7.g-col-md-4.g-col-lg-3.g-col-xl-3 > div.product-list__product-rating > a > div > bl-rating')
                reviews = item.select_one('.product-list__product-area-2.g-col-5.g-col-sm-7.g-col-md-4.g-col-lg-3.g-col-xl-3 > div.product-list__product-rating > a > span')
                promo = item.select_one('.product-list__product-area-3.g-col-5.g-col-sm-7.g-col-md-4.g-start-md-9.g-col-lg-3.g-start-lg-7.g-col-xl-3.g-start-xl-7 > div > div > span.price__crossed')
                stock = item.select_one('.product-list__product-area-3.g-col-5.g-col-sm-7.g-col-md-4.g-start-md-9.g-col-lg-3.g-start-lg-7.g-col-xl-3.g-start-xl-7 > button > span')

                if title and price:
                    all_data.append({
                        'Titre': title.text.strip(),
                        'Prix (€)': price.text.replace(',', '.').strip() if price else None,
                        'Note': rating.get('rating') if rating else None,
                        'Avis': reviews.text.strip() if reviews else None,  # Boulanger ne montre pas toujours le nombre d’avis
                        'promo': promo.text.strip() if promo else "0",
                        'Stock' : 'Disponible' if stock else 'Indisponible'
                        })
                    
        print(len(items))      


    except requests.exceptions.RequestException as e:
        print(f"❌ Erreur lors de la requête : {e}")

    time.sleep(2)  # Pause pour éviter le blocage

# Exécution du scraping
for url in url:
        scrape_product(url)

# Conversion en DataFrame Pandas pour visualisation
df = pd.DataFrame(all_data)

# Affichage des résultats
print("\n📊 Résultats du scraping :")
print(df)

# Sauvegarde en CSV
df.to_csv("resultats_scrappiboul2.csv", index=False)
# Out:
# 44
#
# 📊 Résultats du scraping :
#                                                 Titre Prix (€)  \
# 0   Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...  149.00€
# 1   Casque\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\tAir...  579.00€
# 2   Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...  279.00€
# 3   Casque\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\tAir...  579.00€
# 4   Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...  199.00€
# 5   Casque\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\tAir...  579.00€
# 6   Casque\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\tAir...  579.00€
# 7   Casque\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\tAir...  579.00€
# 8   Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...  149.99€
# 9   Casque\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\tAir...  549.00€
# 10  Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...  129.99€
# 11  Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...   19.54€
# 12  Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...   19.03€
# 13  Casque\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\tAir...  579.00€
# 14  Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...  149.99€
# 15  Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...  149.99€
# 16  Casque\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\tAir...  499.99€
# 17  Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...  169.99€
# 18  Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...  149.00€
# 19  Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...   90.95€
# 20  Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...  119.99€
# 21  Ecouteurs\n\t\t\t\t\t\t\tSO SEVEN\n\t\t\t\t\t\...   55.86€
# 22  Ecouteurs\n\t\t\t\t\t\t\tSO SEVEN\n\t\t\t\t\t\...   38.09€
# 23  Ecouteurs\n\t\t\t\t\t\t\tSO SEVEN\n\t\t\t\t\t\...   55.86€
# 24  Ecouteurs\n\t\t\t\t\t\t\tSO SEVEN\n\t\t\t\t\t\...   38.09€
# 25  Ecouteurs\n\t\t\t\t\t\t\tSO SEVEN\n\t\t\t\t\t\...   38.09€
# 26  Ecouteurs\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t\t\t\t\...   80.19€
# 27  Ecouteurs\n\t\t\t\t\t\t\tSO SEVEN\n\t\t\t\t\t\...   38.09€
# 28  Ecouteurs\n\t\t\t\t\t\t\tSUDIO\n\t\t\t\t\t\t\t...   56.75€
# 29  Ecouteurs\n\t\t\t\t\t\t\tSUDIO\n\t\t\t\t\t\t\t...   66.30€
# 30  Ecouteurs sport\n\t\t\t\t\t\t\tMUVIT\n\t\t\t\t...   33.92€
# 31  Ecouteurs\n\t\t\t\t\t\t\tSUDIO\n\t\t\t\t\t\t\t...   57.03€
# 32  Ecouteurs\n\t\t\t\t\t\t\tSUDIO\n\t\t\t\t\t\t\t...   53.75€
# 33  Ecouteurs\n\t\t\t\t\t\t\tSUDIO\n\t\t\t\t\t\t\t...   44.15€
# 34  Casque\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\tAir...  499.00€
# 35  Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...  179.00€
# 36  Ecouteurs\n\t\t\t\t\t\t\tSONY\n\t\t\t\t\t\t\ti...   17.48€
# 37  Ecouteurs\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\t...  143.00€
# 38  Ecouteurs\n\t\t\t\t\t\t\tSUDIO\n\t\t\t\t\t\t\t...   86.56€
# 39  Ecouteurs\n\t\t\t\t\t\t\tMUVIT\n\t\t\t\t\t\t\t...   21.53€
# 40  Ecouteurs\n\t\t\t\t\t\t\tSUDIO\n\t\t\t\t\t\t\t...   55.19€
# 41  Ecouteurs\n\t\t\t\t\t\t\tSUDIO\n\t\t\t\t\t\t\t...   44.65€
# 42  Ecouteurs\n\t\t\t\t\t\t\tSUDIO\n\t\t\t\t\t\t\t...   65.69€
# 43  Ecouteurs\n\t\t\t\t\t\t\tSUDIO\n\t\t\t\t\t\t\t...   45.64€
#
#                   Note   Avis     promo       Stock
# 0    4.576900005340576   (52)         0  Disponible
# 1   4.6666998863220215   (18)         0  Disponible
# 2    4.775000095367432  (200)         0  Disponible
# 3                  5.0    (6)         0  Disponible
# 4    4.659999847412109   (50)         0  Disponible
# 5                 None   None         0  Disponible
# 6                  5.0    (3)         0  Disponible
# 7                  5.0    (1)         0  Disponible
# 8                 None   None   199,99€  Disponible
# 9     4.63040018081665   (92)   579,00€  Disponible
# 10                None   None   179,99€  Disponible
# 11  4.6666998863220215   (21)         0  Disponible
# 12                 4.5    (6)         0  Disponible
# 13    4.63040018081665   (92)         0  Disponible
# 14                None   None         0  Disponible
# 15  3.0952000617980957   (21)         0  Disponible
# 16                2.75    (4)         0  Disponible
# 17  4.4608001708984375  (102)         0  Disponible
# 18   4.664700031280518  (996)         0  Disponible
# 19   4.074100017547607   (27)         0  Disponible
# 20   3.200000047683716    (5)         0  Disponible
# 21                None   None         0  Disponible
# 22                None   None         0  Disponible
# 23                None   None         0  Disponible
# 24                None   None         0  Disponible
# 25                None   None         0  Disponible
# 26                None   None         0  Disponible
# 27                None   None         0  Disponible
# 28                None   None         0  Disponible
# 29                None   None         0  Disponible
# 30                None   None    39,90€  Disponible
# 31                None   None         0  Disponible
# 32                None   None         0  Disponible
# 33                None   None         0  Disponible
# 34   4.626399993896484   (91)   579,00€  Disponible
# 35  4.5970001220703125   (67)         0  Disponible
# 36                None   None  1245,40€  Disponible
# 37   4.522200107574463  (427)   269,00€  Disponible
# 38                None   None         0  Disponible
# 39                None   None         0  Disponible
# 40                None   None         0  Disponible
# 41                None   None         0  Disponible
# 42                None   None         0  Disponible
# 43                None   None         0  Disponible

# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup


# Définition de l'User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'
}

url = 'https://www.boulanger.com/c/tous-les-ordinateurs-portables',

# Stockage des résultats
all_data = []

# Fonction de scraping
def scrape_product(url):
    try:
        response = requests.get(url, headers=headers, timeout=900)
        response.raise_for_status()  # Vérification des erreurs HTTP
        soup = BeautifulSoup(response.content, 'html.parser')

        
     
        items = soup.select(f'#product-list > ul > li > article')#main > div.grid.product-list__content
            
        len(items)
        for  item in items :
                title = item.select_one('#productLabel')
                price= item.select_one('.product-list__product-area-3.g-col-5.g-col-sm-7.g-col-md-4.g-start-md-9.g-col-lg-3.g-start-lg-7.g-col-xl-3.g-start-xl-7 > div > p')
                rating = item.select_one('.product-list__product-area-2.g-col-5.g-col-sm-7.g-col-md-4.g-col-lg-3.g-col-xl-3 > div.product-list__product-rating > a > div > bl-rating')
                reviews = item.select_one('.product-list__product-area-2.g-col-5.g-col-sm-7.g-col-md-4.g-col-lg-3.g-col-xl-3 > div.product-list__product-rating > a > span')
                promo = item.select_one('.product-list__product-area-3.g-col-5.g-col-sm-7.g-col-md-4.g-start-md-9.g-col-lg-3.g-start-lg-7.g-col-xl-3.g-start-xl-7 > div > div > span.price__crossed')
                stock = item.select_one('.product-list__product-area-3.g-col-5.g-col-sm-7.g-col-md-4.g-start-md-9.g-col-lg-3.g-start-lg-7.g-col-xl-3.g-start-xl-7 > button > span')

                if title and price:
                    all_data.append({
                        'Titre': title.text.strip(),
                        'Prix (€)': price.text.replace(',', '.').strip() if price else None,
                        'Note': rating.get('rating') if rating else None,
                        'Avis': reviews.text.strip() if reviews else None,  # Boulanger ne montre pas toujours le nombre d’avis
                        'promo': promo.text.strip() if promo else "0",
                        'Stock' : 'Disponible' if stock else 'Indisponible'
                        })
                    
        print(len(items))            


    except requests.exceptions.RequestException as e:
        print(f"❌ Erreur lors de la requête : {e}")

    time.sleep(2)  # Pause pour éviter le blocage

# Exécution du scraping
for url in url:
        scrape_product(url)

# Conversion en DataFrame Pandas pour visualisation
df = pd.DataFrame(all_data)

# Affichage des résultats
print("\n📊 Résultats du scraping :")
print(df)

# Sauvegarde en CSV
df.to_csv("resultats_scrappiboul3.csv", index=False)
# Out:
# 50
#
# 📊 Résultats du scraping :
#                                                 Titre  Prix (€)  \
# 0   Ordinateur portable\n\t\t\t\t\t\t\tHP\n\t\t\t\...   899.99€
# 1   PC Gamer\n\t\t\t\t\t\t\tMSI\n\t\t\t\t\t\t\tThi...   699.99€
# 2   Ordinateur Apple\n\t\t\t\t\t\t\tMACBOOK\n\t\t\...  1299.00€
# 3   Ordinateur portable\n\t\t\t\t\t\t\tSAMSUNG\n\t...  1619.99€
# 4   PC Gamer\n\t\t\t\t\t\t\tHP\n\t\t\t\t\t\t\tOMEN...  1599.99€
# 5   Ordinateur portable\n\t\t\t\t\t\t\tMICROSOFT\n...  1369.00€
# 6   Ordinateur portable\n\t\t\t\t\t\t\tHP\n\t\t\t\...   479.99€
# 7   Ordinateur portable\n\t\t\t\t\t\t\tHP\n\t\t\t\...   749.99€
# 8   Ordinateur portable\n\t\t\t\t\t\t\tSAMSUNG\n\t...   499.00€
# 9   PC Hybride\n\t\t\t\t\t\t\tHP\n\t\t\t\t\t\t\tPa...   799.99€
# 10  Ordinateur portable\n\t\t\t\t\t\t\tHP\n\t\t\t\...   429.99€
# 11  Ordinateur Apple\n\t\t\t\t\t\t\tMACBOOK\n\t\t\...   999.00€
# 12  Ordinateur portable\n\t\t\t\t\t\t\tSAMSUNG\n\t...  1799.99€
# 13  Ordinateur portable\n\t\t\t\t\t\t\tLENOVO\n\t\...   699.99€
# 14  Ordinateur portable\n\t\t\t\t\t\t\tASUS\n\t\t\...  1049.99€
# 15  Ordinateur portable\n\t\t\t\t\t\t\tLENOVO\n\t\...   429.99€
# 16  Ordinateur portable\n\t\t\t\t\t\t\tLENOVO\n\t\...   449.99€
# 17  Ordinateur portable\n\t\t\t\t\t\t\tASUS\n\t\t\...   999.99€
# 18  PC Gamer\n\t\t\t\t\t\t\tASUS\n\t\t\t\t\t\t\tTU...  1799.99€
# 19  Ordinateur Apple\n\t\t\t\t\t\t\tMACBOOK\n\t\t\...  1199.00€
# 20  PC Gamer\n\t\t\t\t\t\t\tHP\n\t\t\t\t\t\t\tVict...  1299.99€
# 21  PC Gamer\n\t\t\t\t\t\t\tASUS\n\t\t\t\t\t\t\tVi...  1299.99€
# 22  PC Hybride\n\t\t\t\t\t\t\tLENOVO\n\t\t\t\t\t\t...   649.99€
# 23  Chromebook\n\t\t\t\t\t\t\tLENOVO\n\t\t\t\t\t\t...   349.99€
# 24  PC Gamer\n\t\t\t\t\t\t\tLENOVO\n\t\t\t\t\t\t\t...  1299.99€
# 25  Chromebook\n\t\t\t\t\t\t\tACER\n\t\t\t\t\t\t\t...   299.00€
# 26  Ordinateur portable\n\t\t\t\t\t\t\tLENOVO\n\t\...   269.99€
# 27  Ordinateur portable\n\t\t\t\t\t\t\tLENOVO\n\t\...   599.99€
# 28  Ordinateur portable\n\t\t\t\t\t\t\tHP\n\t\t\t\...   599.99€
# 29  Chromebook\n\t\t\t\t\t\t\tASUS\n\t\t\t\t\t\t\t...   399.99€
# 30  Ordinateur portable\n\t\t\t\t\t\t\tASUS\n\t\t\...   269.99€
# 31  Ordinateur Apple\n\t\t\t\t\t\t\tMACBOOK\n\t\t\...  1069.99€
# 32  PC Gamer\n\t\t\t\t\t\t\tLENOVO\n\t\t\t\t\t\t\t...  2999.00€
# 33  Ordinateur Apple\n\t\t\t\t\t\t\tMACBOOK\n\t\t\...  1599.00€
# 34  PC Gamer\n\t\t\t\t\t\t\tSKILLKORP\n\t\t\t\t\t\...   799.99€
# 35  PC Gamer\n\t\t\t\t\t\t\tHP\n\t\t\t\t\t\t\tOMEN...  1799.99€
# 36  Ordinateur Apple\n\t\t\t\t\t\t\tMACBOOK\n\t\t\...  1299.00€
# 37  PC Gamer\n\t\t\t\t\t\t\tHP\n\t\t\t\t\t\t\tOMEN...  1499.99€
# 38  Ordinateur portable\n\t\t\t\t\t\t\tASUS\n\t\t\...  2499.99€
# 39  Ordinateur portable\n\t\t\t\t\t\t\tACER\n\t\t\...   899.99€
# 40  PC Gamer\n\t\t\t\t\t\t\tHP\n\t\t\t\t\t\t\tOMEN...  1599.99€
# 41  PC Hybride\n\t\t\t\t\t\t\tLENOVO\n\t\t\t\t\t\t...   999.99€
# 42  PC Gamer\n\t\t\t\t\t\t\tMSI\n\t\t\t\t\t\t\tSte...  3799.99€
# 43  PC Gamer\n\t\t\t\t\t\t\tMSI\n\t\t\t\t\t\t\tCre...  1299.99€
# 44  Ordinateur Apple\n\t\t\t\t\t\t\tMACBOOK\n\t\t\...  1899.00€
# 45  Ordinateur portable\n\t\t\t\t\t\t\tSAMSUNG\n\t...   719.99€
# 46  Ordinateur portable\n\t\t\t\t\t\t\tASUS\n\t\t\...  2999.99€
# 47  PC Gamer\n\t\t\t\t\t\t\tASUS\n\t\t\t\t\t\t\tRO...  2499.99€
# 48  PC Gamer\n\t\t\t\t\t\t\tMSI\n\t\t\t\t\t\t\tKat...  1899.99€
# 49  PC Hybride\n\t\t\t\t\t\t\tMICROSOFT\n\t\t\t\t\...  1599.00€
#
#                   Note   Avis     promo       Stock
# 0                 4.75    (4)  1299,99€  Disponible
# 1    4.400000095367432    (5)   799,00€  Disponible
# 2                  5.0   (11)         0  Disponible
# 3    4.900000095367432   (10)  1799,99€  Disponible
# 4                  5.0    (3)  1799,00€  Disponible
# 5                 None   None         0  Disponible
# 6      4.2221999168396    (9)         0  Disponible
# 7                  5.0    (1)   799,99€  Disponible
# 8    4.756800174713135   (37)   529,00€  Disponible
# 9                  5.0    (2)   899,00€  Disponible
# 10               4.875    (8)         0  Disponible
# 11   4.787600040435791  (113)         0  Disponible
# 12                 5.0   (10)  2049,99€  Disponible
# 13  4.3333001136779785    (9)         0  Disponible
# 14   4.571400165557861    (7)  1203,04€  Disponible
# 15   4.769199848175049   (13)         0  Disponible
# 16   4.714300155639648    (7)         0  Disponible
# 17                 4.5    (8)         0  Disponible
# 18                 4.0    (9)         0  Disponible
# 19                 5.0    (6)         0  Disponible
# 20   4.285699844360352   (21)         0  Disponible
# 21    4.13040018081665   (23)         0  Disponible
# 22  3.6666998863220215    (3)         0  Disponible
# 23   4.800000190734863    (5)         0  Disponible
# 24                None   None         0  Disponible
# 25                 4.0    (1)         0  Disponible
# 26  4.6666998863220215    (6)   302,62€  Disponible
# 27   4.740699768066406   (27)   703,61€  Disponible
# 28   4.599999904632568    (5)         0  Disponible
# 29   4.653800010681152   (26)         0  Disponible
# 30   3.764699935913086   (17)         0  Disponible
# 31                 5.0    (1)         0  Disponible
# 32                None   None  4299,99€  Disponible
# 33                 5.0    (2)         0  Disponible
# 34   4.705900192260742   (17)         0  Disponible
# 35                None   None  1999,99€  Disponible
# 36                4.75    (4)         0  Disponible
# 37  4.6666998863220215    (3)         0  Disponible
# 38                 4.5    (4)         0  Disponible
# 39                None   None  1099,99€  Disponible
# 40                 5.0    (1)  1699,99€  Disponible
# 41                 4.0    (4)         0  Disponible
# 42                 4.0    (1)         0  Disponible
# 43                None   None  1399,00€  Disponible
# 44   4.800000190734863    (5)         0  Disponible
# 45                 4.0    (6)   799,99€  Disponible
# 46                 5.0    (1)         0  Disponible
# 47                 5.0    (1)         0  Disponible
# 48                 5.0    (3)  1999,99€  Disponible
# 49                 4.5    (4)         0  Disponible

# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup


# Définition de l'User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'
}

url = 'https://www.boulanger.com/c/smartphone-telephone-portable',

# Stockage des résultats
all_data = []

# Fonction de scraping
def scrape_product(url):
    try:
        response = requests.get(url, headers=headers, timeout=900)
        response.raise_for_status()  # Vérification des erreurs HTTP
        soup = BeautifulSoup(response.content, 'html.parser')

        
     
        items = soup.select(f'#product-list > ul > li > article')#main > div.grid.product-list__content
            
        len(items)
        for  item in items :
                title = item.select_one('#productLabel')
                price= item.select_one('.product-list__product-area-3.g-col-5.g-col-sm-7.g-col-md-4.g-start-md-9.g-col-lg-3.g-start-lg-7.g-col-xl-3.g-start-xl-7 > div > p')
                rating = item.select_one('.product-list__product-area-2.g-col-5.g-col-sm-7.g-col-md-4.g-col-lg-3.g-col-xl-3 > div.product-list__product-rating > a > div > bl-rating')
                reviews = item.select_one('.product-list__product-area-2.g-col-5.g-col-sm-7.g-col-md-4.g-col-lg-3.g-col-xl-3 > div.product-list__product-rating > a > span')
                promo = item.select_one('.product-list__product-area-3.g-col-5.g-col-sm-7.g-col-md-4.g-start-md-9.g-col-lg-3.g-start-lg-7.g-col-xl-3.g-start-xl-7 > div > div > span.price__crossed')
                stock = item.select_one('.product-list__product-area-3.g-col-5.g-col-sm-7.g-col-md-4.g-start-md-9.g-col-lg-3.g-start-lg-7.g-col-xl-3.g-start-xl-7 > button > span')

                if title and price:
                    all_data.append({
                        'Titre': title.text.strip(),
                        'Prix (€)': price.text.replace(',', '.').strip() if price else None,
                        'Note': rating.get('rating') if rating else None,
                        'Avis': reviews.text.strip() if reviews else None,  # Boulanger ne montre pas toujours le nombre d’avis
                        'promo': promo.text.strip() if promo else "0",
                        'Stock' : 'Disponible' if stock else 'Indisponible'
                        })
                    
        print(len(items))          


    except requests.exceptions.RequestException as e:
        print(f"❌ Erreur lors de la requête : {e}")

    time.sleep(2)  # Pause pour éviter le blocage

# Exécution du scraping
for url in url:
        scrape_product(url)

# Conversion en DataFrame Pandas pour visualisation
df = pd.DataFrame(all_data)

# Affichage des résultats
print("\n📊 Résultats du scraping :")
print(df)

# Sauvegarde en CSV
df.to_csv("resultats_scrappiboul1.csv", index=False)
# Out:
# 50
#
# 📊 Résultats du scraping :
#                                                 Titre  Prix (€)  \
# 0   Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...  1471.99€
# 1   Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...   502.04€
# 2   Smartphone\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t\t\t\t...   461.99€
# 3   Smartphone\n\t\t\t\t\t\t\tGOOGLE\n\t\t\t\t\t\t...   949.99€
# 4   Smartphone\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t\t\t\t...  1001.99€
# 5   Smartphone\n\t\t\t\t\t\t\tHONOR\n\t\t\t\t\t\t\...   301.99€
# 6   Smartphone\n\t\t\t\t\t\t\tGOOGLE\n\t\t\t\t\t\t...   429.00€
# 7   Smartphone\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t\t\t\t...   299.99€
# 8   Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...   321.99€
# 9   Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...   399.00€
# 10  Smartphone\n\t\t\t\t\t\t\tGOOGLE\n\t\t\t\t\t\t...   751.99€
# 11  Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...  1291.99€
# 12  Smartphone\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t\t\t\t...   371.99€
# 13  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...  1329.99€
# 14  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...   549.00€
# 15  Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...  1472.03€
# 16  Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...   901.99€
# 17  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...   679.99€
# 18  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...   629.99€
# 19  Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...  1005.90€
# 20  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...  1431.99€
# 21  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...  1430.99€
# 22  Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...  1021.99€
# 23  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...   679.99€
# 24  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...   549.00€
# 25  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...   679.99€
# 26  Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...   988.90€
# 27  Smartphone\n\t\t\t\t\t\t\tGOOGLE\n\t\t\t\t\t\t...   599.00€
# 28  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...   817.00€
# 29  Smartphone\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t\t\t\t...   201.99€
# 30  Smartphone\n\t\t\t\t\t\t\tGOOGLE\n\t\t\t\t\t\t...   451.99€
# 31  Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...  1471.99€
# 32  Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...   649.00€
# 33  Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...   699.99€
# 34  Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...   221.99€
# 35  Smartphone\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t\t\t\t...   751.99€
# 36  Smartphone\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t\t\t\t...   579.99€
# 37  Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...   181.99€
# 38  Smartphone\n\t\t\t\t\t\t\tGOOGLE\n\t\t\t\t\t\t...   351.99€
# 39  Smartphone\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t\t\t\t...   221.99€
# 40  Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...  1001.99€
# 41  Smartphone\n\t\t\t\t\t\t\tSAMSUNG\n\t\t\t\t\t\...   649.00€
# 42  Smartphone\n\t\t\t\t\t\t\tXIAOMI\n\t\t\t\t\t\t...   751.99€
# 43  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...  1399.00€
# 44  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...  1181.99€
# 45  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...  1169.00€
# 46  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...   921.99€
# 47  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...   809.00€
# 48  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...  1299.00€
# 49  Smartphone\n\t\t\t\t\t\t\tAPPLE\n\t\t\t\t\t\t\...  1311.99€
#
#                   Note   Avis     promo       Stock
# 0                  5.0    (5)         0  Disponible
# 1    4.550000190734863   (40)         0  Disponible
# 2                  5.0    (1)   501,99€  Disponible
# 3                  5.0    (3)         0  Disponible
# 4                  5.0    (1)         0  Disponible
# 5                 None   None   381,99€  Disponible
# 6               4.1875   (16)         0  Disponible
# 7    4.028600215911865   (35)   371,06€  Disponible
# 8    4.692299842834473   (13)   351,04€  Disponible
# 9                 3.75   (12)   449,00€  Disponible
# 10                 5.0    (1)   901,08€  Disponible
# 11                None   None         0  Disponible
# 12                None   None   401,99€  Disponible
# 13   4.782100200653076  (179)         0  Disponible
# 14   4.621799945831299  (357)   568,06€  Disponible
# 15                4.75   (36)         0  Disponible
# 16   4.837800025939941   (37)  1001,04€  Disponible
# 17   4.754199981689453  (118)   698,06€  Disponible
# 18                None   None         0  Disponible
# 19   4.933300018310547   (30)         0  Disponible
# 20  4.7769999504089355  (148)  1479,99€  Disponible
# 21  4.7769999504089355  (148)  1479,99€  Disponible
# 22   4.714300155639648    (7)  1121,04€  Disponible
# 23   4.754199981689453  (118)   698,06€  Disponible
# 24  4.6219000816345215  (357)   568,06€  Disponible
# 25   4.754199981689453  (118)   698,06€  Disponible
# 26   4.933300018310547   (30)         0  Disponible
# 27  4.6132001876831055   (62)         0  Disponible
# 28  4.6666998863220215   (51)         0  Disponible
# 29   4.311600208282471  (138)         0  Disponible
# 30                 4.5    (4)         0  Disponible
# 31                 5.0   (15)         0  Disponible
# 32   4.785699844360352   (14)         0  Disponible
# 33  4.6296000480651855   (27)   801,04€  Disponible
# 34                 5.0    (9)   252,04€  Disponible
# 35   4.555600166320801    (9)         0  Disponible
# 36                None   None  1002,10€  Disponible
# 37   4.111100196838379    (9)   201,99€  Disponible
# 38   4.171899795532227   (64)         0  Disponible
# 39                None   None   251,99€  Disponible
# 40                 4.0    (5)  1202,04€  Disponible
# 41                None   None         0  Disponible
# 42  4.6666998863220215    (3)         0  Disponible
# 43  4.7769999504089355  (148)  1479,99€  Disponible
# 44  4.7769999504089355  (148)  1229,99€  Disponible
# 45  4.7769999504089355  (148)  1229,99€  Disponible
# 46   4.735899925231934   (53)   971,06€  Disponible
# 47   4.815999984741211  (163)   870,07€  Disponible
# 48  4.7769999504089355  (148)  1359,99€  Disponible
# 49  4.7769999504089355  (148)  1359,99€  Disponible
